# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280200-max/Alajandra-desarollo-de-algoritmo/blob/main/Actividad_9_Diagrama_y_c%C3%B3digo%2C_coste_de_env%C3%ADo_en_una_tienda_en_linea_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alejandra Rivera Valenzuela 2-H

# %%
# 1. Solicitamos el valor de la compra
Precio_producto = float(input("Introduce el valor de tu compra en pesos: "))
#2. Aplicamos la estroctura condicional (if/else)
if Precio_producto >= 800:
   envio = 0
   print("Felicidades tu envio es gratis.")
else:
   envio = 150
   print("El costo de envio es de 150 pesos")
# 3. Calculamos el precio final
Precio_Final = Precio_producto + envio
# 4. Mostramos el resultado
print("El precio final de tu compra es de: ", Precio_Final)
# Out:
# Introduce el valor de tu compra en pesos: 2000
# Felicidades tu envio es gratis.
# El precio final de tu compra es de:  2000.0

# %%
# 1. Solicitamos el valor de la compra
Precio_producto = float(input("Introduce el valor de tu compra en pesos: "))
#2. Aplicamos la estroctura condicional (if/else)
if Precio_producto >= 800:
   envio = 0
   print("Felicidades tu envio es gratis.")
else:
   envio = 150
   print("El costo de envio es de 150 pesos")
# 3. Calculamos el precio final
Precio_Final = Precio_producto + envio
# 4. Mostramos el resultado
print("El precio final de tu compra es de: ", Precio_Final)
# Out:
# Introduce el valor de tu compra en pesos: 700
# El costo de envio es de 150 pesos
# El precio final de tu compra es de:  850.0

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051280200-max/Alajandra-desarollo-de-algoritmo/refs/heads/main/DiagramaAlevaluuu.png)
